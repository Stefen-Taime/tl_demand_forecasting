# %% [markdown]
# # TLC Demand Forecasting\n\nNotebook local d'exploration rapide. Les traitements de reference restent dans `scripts/`.

# %%
from pathlib import Path\n\nimport pandas as pd\n\nraw_files = sorted(Path('../data/raw').glob('*_tripdata_*.parquet'))\nraw_files[:5]

# %%
features = pd.read_parquet('../data/processed/features.parquet')\nfeatures.head()
